# %%
import sys
sys.path.append('..')
import os
os.chdir('..')
import linearmodels
from models.models import Segment

# %%
# Segment level analysis
seg = Segment()

#what does this look like
seg
print(seg)

#need help interpreting columns
seg.describe("")


#lets look at model 1
model = seg.model_1()

#what are we doing with this model
print(model)

#this is the data we are using 
df = model.model_data
# Out:
# flight route and cost by segement of trip
# preparing data
# /Users/austinpeel/.pyenv/versions/3.6.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3296: DtypeWarning: Columns (7,8,15,16,24,25,26,27,71,72,74,75,79,85,130) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# This model looks at the ratio of YCA fare to XCA fare and the effect on price

# %%
df.head()
# Out:
#     21 Days  DG_x  DashCA_x  Other_x  YCA_x    Year airline_carrier_name  \
# 14        0     0         1        0      0  2018.0   Southwest Airlines
# 15        0     0         1        0      0  2018.0   Southwest Airlines
# 18        0     1         0        0      0  2018.0      Delta Air Lines
# 19        0     1         0        0      0  2018.0      Delta Air Lines
# 28        0     1         0        0      0  2018.0      Delta Air Lines
#
#     awarded  base_fare cabin_svc_class_of_segment  ... daily_demand  \
# 14        1      90.23                    ECONOMY  ...            1
# 15        1      90.23                    ECONOMY  ...            1
# 18        1      90.23                    ECONOMY  ...            3
# 19        1      90.23                    ECONOMY  ...            3
# 28        1      90.23                    ECONOMY  ...            4
#
#    dash_per_mile YCA_per_mile  cost_per_mile  city_pair_ratio  \
# 14        0.1633     0.250842       0.187205         0.651007
# 15        0.1633     0.250842       0.187205         0.651007
# 18        0.1633     0.250842       0.187205         0.651007
# 19        0.1633     0.250842       0.187205         0.651007
# 28        0.1633     0.250842       0.187205         0.651007
#
#     market_share_log booking_advanced_days  Organization  \
# 14         -0.585549                     5      GSA-4PEE
# 15         -0.585549                     5      GSA-4PEE
# 18         -0.585549                     1      GSA-4PPB
# 19         -0.585549                     1      GSA-4PPB
# 28         -0.585549                     6      GSA-4PME
#
#                   Purpose  GRADE_CODE
# 14  MISSION (OPERATIONAL)         NaN
# 15  MISSION (OPERATIONAL)         NaN
# 18  MISSION (OPERATIONAL)         NaN
# 19  MISSION (OPERATIONAL)         NaN
# 28  MISSION (OPERATIONAL)         NaN
#
# [5 rows x 42 columns]
